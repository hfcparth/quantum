# %%
# Importing standard Qiskit libraries
from qiskit import *
from qiskit.tools.jupyter import *
from qiskit.visualization import *


# qiskit-ibmq-provider has been deprecated.
# Please see the Migration Guides in https://ibm.biz/provider_migration_guide for more detail.
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler, Estimator, Session, Options



# Invoke a primitive. For more details see https://qiskit.org/documentation/partners/qiskit_ibm_runtime/tutorials.html
# result = Sampler("ibmq_qasm_simulator").run(circuits).result()

# %%
qr=QuantumRegister(4)
c1=ClassicalRegister(2)
c2=ClassicalRegister(2)
qc=QuantumCircuit(qr,c1,c2)
qc.measure(qr[0:2],c1)
qc.measure(qr[2:4],c2)
qc.draw(output="mpl")

# %%
qc=QuantumCircuit(1)
qc.measure_all()
qc.draw(output="mpl")

# %%
qc=QuantumCircuit(2)
theta=2*3.042/3
qc.crz(theta,0,1)
qc.draw(output="mpl")

# %%
type(qc.draw(output="mpl"))
# Out:
# matplotlib.figure.Figure

# %%
backend=BasicAer.get_backend('qasm_simulator')

# %%
job=execute(qc,backend)
job.backend()
# Out:
# No classical registers in circuit "circuit-123", counts will be empty.
# <QasmSimulatorPy('qasm_simulator')>

# %%
bell=QuantumCircuit(2)
bell.h(0)
bell.h(1)
mes=QuantumCircuit(2,2)
mes.measure([0,1],[0,1])
mes.draw()
# Out:
#      ┌─┐
# q_0: ┤M├───
#      └╥┘┌─┐
# q_1: ─╫─┤M├
#       ║ └╥┘
# c: 2/═╩══╩═
#       0  1

# %%
bell.barrier()
bell.draw()
# Out:
#      ┌───┐ ░
# q_0: ┤ H ├─░─
#      ├───┤ ░
# q_1: ┤ H ├─░─
#      └───┘ ░

# %%
qcn=bell.compose(mes)
qcn.draw()
# Out:
#      ┌───┐ ░ ┌─┐
# q_0: ┤ H ├─░─┤M├───
#      ├───┤ ░ └╥┘┌─┐
# q_1: ┤ H ├─░──╫─┤M├
#      └───┘ ░  ║ └╥┘
# c: 2/═════════╩══╩═
#               0  1

# %%
qreg_q = QuantumRegister(2, 'q')

circuit = QuantumCircuit(qreg_q)

circuit.cx(0,1)
circuit.cx(0,1)
backend=BasicAer.get_backend('unitary_simulator')
execute(circuit,backend).result().get_unitary(circuit,1)
# Out:
# array([[1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j]])

# %%
figure = plot_bloch_multivector([3.142,3.142])
figure.savefig('sphere.png')

# %%
from qiskit import QuantumCircuit
qc=QuantumCircuit(2)
qc.h(0)
qc.cx(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       2 qc=QuantumCircuit(2)
#       3 qc.h(0)
# ----> 4 qc.cx(1)
#
# TypeError: QuantumCircuit.cx() missing 1 required positional argument: 'target_qubit'

# %%
qc=QuantumCircuit(1,1)
qc.measure(0,0)
qc.draw(output="mpl")

# %%
from qiskit.visualization import plot_bloch_multivector
bell=QuantumCircuit(2)
bell.h(0)
bell.cx(0,1)
backend=Aer.get_backend('vector_simulator')
result=execute(bell,backend).result()
plot_bloch_multivector(result)
# Out:
# ---------------------------------------------------------------------------
# QiskitBackendNotFoundError                Traceback (most recent call last)
# Cell In[38], line 5
#       3 bell.h(0)
#       4 bell.cx(0,1)
# ----> 5 backend=Aer.get_backend('vector_simulator')
#       6 result=execute(bell,backend).result()
#       7 plot_bloch_multivector(result)
#
# File ~\anaconda3\lib\site-packages\qiskit_aer\aerprovider.py:75, in AerProvider.get_backend(self, name, **kwargs)
#      67 if name == "pulse_simulator":
#      68     warnings.warn(
#      69         "The Pulse simulator backend in Qiskit Aer is deprecated and will "
#      70         "be removed in a future release. Instead the qiskit-dynamics "
#    (...)
#      73         stacklevel=2,
#      74     )
# ---> 75 return super().get_backend(name=name, **kwargs)
#
# File ~\anaconda3\lib\site-packages\qiskit\providers\provider.py:55, in ProviderV1.get_backend(self, name, **kwargs)
#      53     raise QiskitBackendNotFoundError("More than one backend matches the criteria")
#      54 if not backends:
# ---> 55     raise QiskitBackendNotFoundError("No backend matches the criteria")
#      57 return backends[0]
#
# QiskitBackendNotFoundError: 'No backend matches the criteria'

# %%
qreg_q = QuantumRegister(2, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.measure([0,1],[0,1])
print(type(circuit.draw()))
# Out:
# <class 'qiskit.visualization.circuit.text.TextDrawing'>

# %%
from qiskit.quantum_info import Statevector
sv=Statevector([1,0])
plot_state_qsphere(sv)

# %%
import numpy as np
from qiskit.visualization import plot_bloch_vector

# You can use spherical coordinates instead of cartesian.

plot_bloch_vector([0, 0, -1])

# %%
qreg_q = QuantumRegister(1, 'q')

circuit = QuantumCircuit(qreg_q)

circuit.h(0)
circuit.x(0)
backend=BasicAer.get_backend('unitary_simulator')
execute(circuit,backend).result().get_unitary(circuit,1)
# Out:
# array([[ 0.7+0.j, -0.7-0.j],
#        [ 0.7+0.j,  0.7+0.j]])
